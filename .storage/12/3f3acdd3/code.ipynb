# %%
from metagpt.tools.libs.web_scraping import view_page_element_to_scrape

# Navigate to Google Maps to get location details
google_maps_url = "https://maps.app.goo.gl/k2hiC917oE1z4ynR8"

# View the page content to understand the structure
html_content = await view_page_element_to_scrape(
    url=google_maps_url,
    requirement="Extract business name, address, phone number, coordinates, opening hours, ratings, reviews, and any other business information visible on Google Maps",
    keep_links=False
)

print(html_content)
# Out:
# 2025-11-17 03:24:10.852 | INFO     | metagpt.const:get_metagpt_root:33 - PROJECT_ROOT set from environment variable to /
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 from metagpt.tools.libs.web_scraping import view_page_element_to_scrape
#       3 # Navigate to Google Maps to get location details
#       4 google_maps_url = "https://maps.app.goo.gl/k2hiC917oE1z4ynR8"
#
# ModuleNotFoundError: No module named 'metagpt.tools.libs.web_scraping'

# %%
from metagpt.tools.libs.terminal import Terminal

# Install required packages
terminal = Terminal()
await terminal.run('pip install requests beautifulsoup4 lxml')

import requests
from bs4 import BeautifulSoup
import json

# Navigate to Google Maps to get location details
google_maps_url = "https://maps.app.goo.gl/k2hiC917oE1z4ynR8"

# Set up headers to mimic a browser request
headers = {
    'User-Agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/91.0.4472.124 Safari/537.36'
}

# Fetch the page
response = requests.get(google_maps_url, headers=headers, allow_redirects=True)
print(f"Status Code: {response.status_code}")
print(f"Final URL: {response.url}")

# Parse the HTML content
soup = BeautifulSoup(response.content, 'html.parser')

# Save the HTML for analysis
html_content = soup.prettify()
print("\n=== HTML Content Preview (first 2000 characters) ===")
print(html_content[:2000])

# Try to extract some basic information
print("\n=== Attempting to extract information ===")

# Look for meta tags which often contain structured data
meta_tags = soup.find_all('meta')
for meta in meta_tags[:10]:  # Print first 10 meta tags
    print(f"Meta tag: {meta.attrs}")
# Out:
# Status Code: 200
# Final URL: https://www.google.com/maps/place/Ministry+of+Coffee/@52.2209216,20.9856723,14z/data=!4m7!3m6!1s0x47192ac234bcf951:0x746dff58922432ed!8m2!3d52.2187904!4d21.018337!15sChJrYXdpYXJuaWEgV2Fyc3phd2FaFCISa2F3aWFybmlhIHdhcnN6YXdhkgEEY2FmZZoBI0NoWkRTVWhOTUc5blMwVkpRMEZuU1VNeU1UUnFlbGhuRUFFqgFZCg0vZy8xMWwyeTE5YzhxEAEqDSIJa2F3aWFybmlhKAsyHxABIhvvy0RtTSaZCPxl7-05PqaFzXgMHVfyCuxnggYyFhACIhJrYXdpYXJuaWEgd2Fyc3phd2HgAQD6AQQIABBA!16s%2Fg%2F1jglxr_cr?entry=tts&g_ep=EgoyMDI1MTExMi4wIPu8ASoASAFQAw%3D%3D&skid=8c11d7ad-a713-4178-9c89-2c3ee5b8ef02
#
# === HTML Content Preview (first 2000 characters) ===
# <!DOCTYPE html>
# <html itemscope="" itemtype="http://schema.org/Place" lang="zh-HK">
#  <head>
#   <link as="script" href="/maps/_/js/k=maps.m.zh_TW.irAKC2GeKZk.2021.O/m=sc2,per,mo,lp,ep,ti,stx,ds,dwi,enr,pwd,dw,ppl,log,std,b/am=5AAASAIQ/rt=j/d=1/rs=ACT90oGE8b_xW4w3HaqEAfZ6H4KxkOjvuw?wli=m.Thap40HfJpI.loadSv.O%3A%3Bm.yCYLOJH5Wao.mapcore.O%3A%3B&amp;cb=M" nonce="VieO274lcn51A13mI5WHeg" rel="preload" type="application/javascript"/>
#   <link href="/maps/preview/opensearch.xml?hl=zh-TW" rel="search" title="Google 地圖" type="application/opensearchdescription+xml"/>
#   <title>
#    Google 地圖
#   </title>
#   <meta content="利用「Google 地圖」尋找本地商家、檢視地圖或規劃行車路線。" name="Description"/>
#   <meta content="Ministry of Coffee · Marszałkowska 27/35, 00-639 Warszawa, 波蘭" itemprop="name"/>
#   <meta content="Ministry of Coffee · Marszałkowska 27/35, 00-639 Warszawa, 波蘭" property="og:title"/>
#   <meta content="https://lh3.googleusercontent.com/p/AF1QipOI1cimOljqM4rY2hG8Lla1rLzwJzk2SodS52xW=w900-h900-p-k-no" itemprop="image"/>
#   <meta content="https://lh3.googleusercontent.com/p/AF1QipOI1cimOljqM4rY2hG8Lla1rLzwJzk2SodS52xW=w900-h900-p-k-no" property="og:image"/>
#   <meta content="900" property="og:image:width"/>
#   <meta content="900" property="og:image:height"/>
#   <meta content="★★★★★ · 咖啡廳" itemprop="description"/>
#   <meta content="★★★★★ · 咖啡廳" property="og:description"/>
#   <meta content="Ministry of Coffee · Marszałkowska 27/35, 00-639 Warszawa, 波蘭" property="og:site_name"/>
#   <meta content="summary" name="twitter:card"/>
#   <meta content="Anm+hhtuh7NJguqSnXHEAIqqMaV+GXCks8WYXHJKF7l6AeYMj+wO+fi9OdDqFnJTg9t0492DykVxx4jpvFbxnA8AAABseyJvcmlnaW4iOiJodHRwczovL2dvb2dsZS5jb206NDQzIiwiZmVhdHVyZSI6IlByaXZhY3lTYW5kYm94QWRzQVBJcyIsImV4cGlyeSI6MTY5NTE2Nzk5OSwiaXNTdWJkb21haW4iOnRydWV9" http-equiv="origin-trial"/>
#   <meta content="initial-scale=1.0, maximum-scale=1.0, minimum-scale=1.0, user-scalable=no" name="viewport"/>
#   <meta content="notranslate" name="google"/>
#   <meta content="origin" name="referrer"/>
#   <meta con
#
# === Attempting to extract information ===
# Meta tag: {'content': '利用「Google 地圖」尋找本地商家、檢視地圖或規劃行車路線。', 'name': 'Description'}
# Meta tag: {'content': 'Ministry of Coffee · Marszałkowska 27/35, 00-639 Warszawa, 波蘭', 'itemprop': 'name'}
# Meta tag: {'content': 'Ministry of Coffee · Marszałkowska 27/35, 00-639 Warszawa, 波蘭', 'property': 'og:title'}
# Meta tag: {'content': 'https://lh3.googleusercontent.com/p/AF1QipOI1cimOljqM4rY2hG8Lla1rLzwJzk2SodS52xW=w900-h900-p-k-no', 'itemprop': 'image'}
# Meta tag: {'content': 'https://lh3.googleusercontent.com/p/AF1QipOI1cimOljqM4rY2hG8Lla1rLzwJzk2SodS52xW=w900-h900-p-k-no', 'property': 'og:image'}
# Meta tag: {'content': '900', 'property': 'og:image:width'}
# Meta tag: {'content': '900', 'property': 'og:image:height'}
# Meta tag: {'content': '★★★★★ · 咖啡廳', 'itemprop': 'description'}
# Meta tag: {'content': '★★★★★ · 咖啡廳', 'property': 'og:description'}
# Meta tag: {'content': 'Ministry of Coffee · Marszałkowska 27/35, 00-639 Warszawa, 波蘭', 'property': 'og:site_name'}

# %%
from metagpt.tools.libs.web_scraping import view_page_element_to_scrape

# View the page structure to understand what information is available
html_content = await view_page_element_to_scrape(
    url="https://www.google.com/maps/place/Ministry+of+Coffee/@52.2209216,20.9856723,14z/data=!4m7!3m6!1s0x47192ac234bcf951:0x746dff58922432ed!8m2!3d52.2187904!4d21.018337!15sChJrYXdpYXJuaWEgV2Fyc3phd2FaFCISa2F3aWFybmlhIHdhcnN6YXdhkgEEY2FmZZoBI0NoWkRTVWhOTUc5blMwVkpRMEZuU1VNeU1UUnFlbGhuRUFFqgFZCg0vZy8xMWwyeTE5YzhxEAEqDSIJa2F3aWFybmlhKAsyHxABIhvvy0RtTSaZCPxl7-05PqaFzXgMHVfyCuxnggYyFhACIhJrYXdpYXJuaWEgd2Fyc3phd2HgAQD6AQQIABBA!16s%2Fg%2F1jglxr_cr?entry=ttu&g_ep=EgoyMDI1MTExMi4wIKXMDSoASAFQAw%3D%3D",
    requirement="Extract all information about Ministry of Coffee including: business name, address, phone number, opening hours, rating, reviews count, price range, website URL, images, and all other details visible on the page",
    keep_links=True
)

print("=== Google Maps Page Structure ===")
print(html_content[:5000])  # Print first 5000 characters to see the structure
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[3], line 1
# ----> 1 from metagpt.tools.libs.web_scraping import view_page_element_to_scrape
#       3 # View the page structure to understand what information is available
#       4 html_content = await view_page_element_to_scrape(
#       5     url="https://www.google.com/maps/place/Ministry+of+Coffee/@52.2209216,20.9856723,14z/data=!4m7!3m6!1s0x47192ac234bcf951:0x746dff58922432ed!8m2!3d52.2187904!4d21.018337!15sChJrYXdpYXJuaWEgV2Fyc3phd2FaFCISa2F3aWFybmlhIHdhcnN6YXdhkgEEY2FmZZoBI0NoWkRTVWhOTUc5blMwVkpRMEZuU1VNeU1UUnFlbGhuRUFFqgFZCg0vZy8xMWwyeTE5YzhxEAEqDSIJa2F3aWFybmlhKAsyHxABIhvvy0RtTSaZCPxl7-05PqaFzXgMHVfyCuxnggYyFhACIhJrYXdpYXJuaWEgd2Fyc3phd2HgAQD6AQQIABBA!16s%2Fg%2F1jglxr_cr?entry=ttu&g_ep=EgoyMDI1MTExMi4wIKXMDSoASAFQAw%3D%3D",
#       6     requirement="Extract all information about Ministry of Coffee including: business name, address, phone number, opening hours, rating, reviews count, price range, website URL, images, and all other details visible on the page",
#       7     keep_links=True
#       8 )
#
# ModuleNotFoundError: No module named 'metagpt.tools.libs.web_scraping'
